# %%
import asyncio
import time
import threading

# %%
def fun_1():
    print("Function 1 started")
    time.sleep(10)
    print("Function 1 complete")

def fun_2():
    print("Function 2 started")
    time.sleep(10)
    print("Function 2 complete")    
import threading
import time

def square(num):
    print(f"Square: {num*num}")
    time.sleep(1)

def cube(num):
    print(f"Cube: {num*num*num}")
    time.sleep(1)

# Create the threads
t1 = threading.Thread(target=fun_1)
t2 = threading.Thread(target=fun_2)

# Start the threads
t1.start()
t2.start()

# Wait for the threads to finish
t1.join()
t2.join()

print("Done!")
# Out:
# Function 1 startedFunction 2 started
#
# Function 2 complete
# Function 1 complete
# Done!

# %%
import multiprocessing
import os

def print_square(num):
    """
    Function to print the square of a number.
    """
    print(f"Process ID for Square: {os.getpid()}")
    print(f"Square: {num * num}")

def print_cube(num):
    """
    Function to print the cube of a number.
    """
    print(f"Process ID for Cube: {os.getpid()}")
    print(f"Cube: {num * num * num}")

if __name__ == "__main__":
    # creating processes
    p1 = multiprocessing.Process(target=print_square, args=(10, ))
    p2 = multiprocessing.Process(target=print_cube, args=(10, ))

    # starting process 1
    p1.start()
    # starting process 2
    p2.start()

    # wait until process 1 is finished
    p1.join()
    # wait until process 2 is finished
    p2.join()

    # both processes finished
    print("Done!")

# %%
import threading
import time

# %%
def fun_1():
    print("Function 1 is running")
    time.sleep(5)
    print("Function 1 is complete")

def fun_2():
    print("Function 2 is running")
    time.sleep(5)
    print("Function 2 is complete")   


t1 = threading.Thread(target=fun_1)
t2 = threading.Thread(target=fun_2)  

t1.start()
t2.start()

t1.join()
t2.join()

print("All functions are complete!")
# Out:
# Function 1 is running
# Function 2 is running
# Function 1 is complete
# Function 2 is complete
# All functions are complete!

# %%
import asyncio
import time

async def fun_1():
    print("Function 1 is running")
    await time.sleep(5)
    print("Function 1 is complete")

async def fun_2():
    print("Function 2 is running")
    await time.sleep(5)
    print("Function 2 is complete")   


asyncio.run(asyncio.gather(
        fun_1(),
        fun_2()))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[22], line 15
#      11     await time.sleep(5)
#      12     print("Function 2 is complete")
# ---> 15 asyncio.run(asyncio.gather(
#      16         fun_1(),
#      17         fun_2()))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\runners.py:190, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)    186     asyncio.run(main())
#     187 """
#     188 if events._get_running_loop() is not None:
#     189     # fail fast with short traceback
# --> 190     raise RuntimeError(
#     191         "asyncio.run() cannot be called from a running event loop")
#     193 with Runner(debug=debug, loop_factory=loop_factory) as runner:
#     194     return runner.run(main)
#
# ...
